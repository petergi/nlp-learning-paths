# %% [markdown]
# # Week 4: spaCy Intro (POS + NER)
#
# Goal: explore linguistic annotations and named entities with spaCy.

# %%
import spacy

# Run once in terminal if needed:
# python -m spacy download en_core_web_sm
nlp = spacy.load('en_core_web_sm')
text = 'Apple announced new AI features in California in 2026.'
doc = nlp(text)

[(token.text, token.pos_) for token in doc]

# %%
[(ent.text, ent.label_) for ent in doc.ents]

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)

# %% [markdown]
# ## Try It
#
# 1. Replace the sentence with text from a news article.
# 2. Inspect which entities are found and where spaCy makes mistakes.
